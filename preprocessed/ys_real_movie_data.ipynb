# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df_2005 = pd.read_csv('./data/2005/merged_movies_data_2005.csv')
df_2006 = pd.read_csv('./data/2006/merged_movies_data_2006.csv')
df_2007 = pd.read_csv('./data/2007/merged_movies_data_2007.csv')
df_2008 = pd.read_csv('./data/2008/merged_movies_data_2008.csv')
df_2009 = pd.read_csv('./data/2009/merged_movies_data_2009.csv')
df_2010 = pd.read_csv('./data/2010/merged_movies_data_2010.csv')
df_2011 = pd.read_csv('./data/2011/merged_movies_data_2011.csv')
df_2012 = pd.read_csv('./data/2012/merged_movies_data_2012.csv')
df_2013 = pd.read_csv('./data/2013/merged_movies_data_2013.csv')
df_2014 = pd.read_csv('./data/2014/merged_movies_data_2014.csv')
df_2015 = pd.read_csv('./data/2015/merged_movies_data_2015.csv')
df_2016 = pd.read_csv('./data/2016/merged_movies_data_2016.csv')
df_2017 = pd.read_csv('./data/2017/merged_movies_data_2017.csv')
df_2018 = pd.read_csv('./data/2018/merged_movies_data_2018.csv')
df_2019 = pd.read_csv('./data/2019/merged_movies_data_2019.csv')
df_2020 = pd.read_csv('./data/2020/merged_movies_data_2020.csv')
df_2021 = pd.read_csv('./data/2021/merged_movies_data_2021.csv')
df_2022 = pd.read_csv('./data/2022/merged_movies_data_2022.csv')
df_2023 = pd.read_csv('./data/2023/merged_movies_data_2023.csv')
df_2024 = pd.read_csv('./data/2024/merged_movies_data_2024.csv')

df = pd.concat([df_2005, df_2006,df_2007,df_2008,df_2009,df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021,df_2022,df_2023,df_2024])

df
# Out:
#                                                  Title  \
# 0      1. Star Wars: Episode III - Revenge of the Sith
# 1    2. The Chronicles of Narnia: The Lion, the Wit...
# 2               3. Harry Potter and the Goblet of Fire
# 3                                 4. War of the Worlds
# 4                                         5. King Kong
# ..                                                 ...
# 595                                     596. Vettaiyan
# 596                                        597. Nr. 24
# 597                                      598. Parallel
# 598                               599. Fight or Flight
# 599                                   600. A Sacrifice
#
#                                             Movie Link  Year Duration    MPA  \
# 0    https://www.imdb.com/title/tt0121766/?ref_=sr_t_1  2005   2h 20m  PG-13
# 1    https://www.imdb.com/title/tt0363771/?ref_=sr_t_2  2005   2h 23m     PG
# 2    https://www.imdb.com/title/tt0330373/?ref_=sr_t_3  2005   2h 37m  PG-13
# 3    https://www.imdb.com/title/tt0407304/?ref_=sr_t_4  2005   1h 57m  PG-13
# 4    https://www.imdb.com/title/tt0360717/?ref_=sr_t_5  2005    3h 7m  PG-13
# ..                                                 ...   ...      ...    ...
# 595  https://www.imdb.com/title/tt26936666/?ref_=sr...  2024   2h 43m    NaN
# 596  https://www.imdb.com/title/tt23782584/?ref_=sr...  2024   1h 51m    NaN
# 597  https://www.imdb.com/title/tt14637386/?ref_=sr...  2024   1h 28m    NaN
# 598  https://www.imdb.com/title/tt13652286/?ref_=sr...  2024   2h 46m    NaN
# 599  https://www.imdb.com/title/tt16491560/?ref_=sr...  2024   1h 34m      R
#
#      Rating Votes       budget  grossWorldWide  gross_US_Canada  ...  \
# 0       7.6  867K  113000000.0     850035635.0      380270577.0  ...
# 1       6.9  438K  180000000.0     745013115.0      291710957.0  ...
# 2       7.7  705K  150000000.0     897468952.0      290469928.0  ...
# 3       6.5  485K  132000000.0     603873504.0      234280354.0  ...
# 4       7.2  455K  207000000.0     556906378.0      218080025.0  ...
# ..      ...   ...          ...             ...              ...  ...
# 595     7.1   38K          NaN       2397623.0              NaN  ...
# 596     7.7  3.4K          NaN       3301976.0              NaN  ...
# 597     5.3  1.7K          NaN             NaN              NaN  ...
# 598     7.0   117          NaN             NaN              NaN  ...
# 599     5.1  4.3K          NaN        130017.0              NaN  ...
#
#                                                  stars  \
# 0    ['Hayden Christensen', 'Natalie Portman', 'Ewa...
# 1    ['Tilda Swinton', 'Georgie Henley', 'William M...
# 2    ['Daniel Radcliffe', 'Emma Watson', 'Rupert Gr...
# 3      ['Tom Cruise', 'Dakota Fanning', 'Tim Robbins']
# 4        ['Naomi Watts', 'Jack Black', 'Adrien Brody']
# ..                                                 ...
# 595  ['Fahadh Faasil', 'Amitabh Bachchan', 'Rajinik...
# 596  ['Mark Noble', 'Lisa Loven Kongsli', 'August W...
# 597  ['Danielle Deadwyler', 'Aldis Hodge', 'Edwin H...
# 598  ['Josh Hartnett', 'Katee Sackhoff', 'Charithra...
# 599        ['Eric Bana', 'Sadie Sink', 'Sylvia Hoeks']
#
#                                                 genres  \
# 0    ['Action Epic', 'Adventure Epic', 'Dark Fantas...
# 1    ['Fantasy Epic', 'Supernatural Fantasy', 'Swor...
# 2    ['Sword & Sorcery', 'Teen Adventure', 'Teen Fa...
# 3    ['Action Epic', 'Adventure Epic', 'Alien Invas...
# 4    ['Adventure Epic', 'Dark Romance', 'Dinosaur A...
# ..                                                 ...
# 595  ['Cop Drama', 'One-Person Army Action', 'Actio...
# 596  ['Docudrama', 'Epic', 'Period Drama', 'Biograp...
# 597                    ['Drama', 'Sci-Fi', 'Thriller']
# 598                               ['Action', 'Comedy']
# 599         ['Drama', 'Horror', 'Mystery', 'Thriller']
#
#                                       countries_origin  \
# 0    ['United States', 'Italy', 'Switzerland', 'Tha...
# 1                  ['United Kingdom', 'United States']
# 2                  ['United Kingdom', 'United States']
# 3                                    ['United States']
# 4          ['United States', 'New Zealand', 'Germany']
# ..                                                 ...
# 595                                          ['India']
# 596                                         ['Norway']
# 597                                  ['United States']
# 598                ['United States', 'United Kingdom']
# 599  ['Germany', 'United States', 'United Kingdom',...
#
#                                      filming_locations  \
# 0               ['Mount Etna, Catania, Sicily, Italy']
# 1    ['Adrspach National Park, Trutnov, Czech Repub...
# 2    ['Glenfinnan Viaduct, Fort William, Highland, ...
# 3       ['JF Kennedy Blvd., Bayonne, New Jersey, USA']
# 4              ['Shelly Bay, Wellington, New Zealand']
# ..                                                 ...
# 595                                                 []
# 596                           ['Rjukan, Tinn, Norway']
# 597                                                 []
# 598                                        ['Hungary']
# 599                                                 []
#
#                                   production_companies  \
# 0    ['Lucasfilm', 'Mestiere Cinema', 'Pandora Films']
# 1             ['Walt Disney Pictures', 'Walden Media']
# 2    ['Warner Bros.', 'Heyday Films', 'Patalex Prod...
# 3    ['Paramount Pictures', 'Dreamworks Pictures', ...
# 4    ['Universal Pictures', 'WingNut Films', 'Big P...
# ..                                                 ...
# 595                               ['Lyca Productions']
# 596              ['SF Norge A/S', 'Motion Blur Films']
# 597  ['Rumble Riot Pictures', 'Hodge Brothers Produ...
# 598  ['Asbury Park Productions', 'The Royal Budapes...
# 599  ['Scott Free Productions', 'Augenschein Filmpr...
#
#                                             Languages wins nominations oscars  \
# 0                                         ['English']    0          64      1
# 1    ['English', 'German', 'Brazilian Sign Language']    0          46      0
# 2                      ['English', 'French', 'Latin']    0          48      1
# 3                                         ['English']    0          49      3
# 4                                         ['English']    0         104      0
# ..                                                ...  ...         ...    ...
# 595                                         ['Tamil']    0           0      0
# 596                                     ['Norwegian']    0           0      0
# 597                                                []    0           0      0
# 598                                       ['English']    0           0      0
# 599                             ['English', 'German']    0           0      0
#
#      release_date
# 0          2005.0
# 1          2005.0
# 2          2005.0
# 3          2005.0
# 4          2005.0
# ..            ...
# 595        2024.0
# 596        2024.0
# 597        2024.0
# 598        2024.0
# 599        2024.0
#
# [10700 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10700 entries, 0 to 599
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  10700 non-null  object
#  1   Movie Link             10700 non-null  object
#  2   Year                   10700 non-null  int64
#  3   Duration               10672 non-null  object
#  4   MPA                    9087 non-null   object
#  5   Rating                 10659 non-null  float64
#  6   Votes                  10659 non-null  object
#  7   budget                 4749 non-null   float64
#  8   grossWorldWide         9812 non-null   float64
#  9   gross_US_Canada        9394 non-null   float64
#  10  opening_weekend_Gross  8901 non-null   float64
#  11  directors              10700 non-null  object
#  12  writers                10700 non-null  object
#  13  stars                  10700 non-null  object
#  14  genres                 10700 non-null  object
#  15  countries_origin       10700 non-null  object
#  16  filming_locations      10700 non-null  object
#  17  production_companies   10700 non-null  object
#  18  Languages              10700 non-null  object
#  19  wins                   10700 non-null  int64
#  20  nominations            10700 non-null  int64
#  21  oscars                 10700 non-null  int64
#  22  release_date           10420 non-null  float64
# dtypes: float64(6), int64(4), object(13)
# memory usage: 2.0+ MB

# %%
# MPA null 값 unrated 로 바꾸기 

df['MPA'] = df['MPA'].fillna('unrated')

# Rating 열에서 null 값 평균으로 대체

rating_mean = df['Rating'].mean()
df['Rating'] = df['Rating'].fillna(rating_mean)

# votes null 값 평균으로 대체 
def convert_votes(vote_str):
    if isinstance(vote_str, str):
        if 'M' in vote_str:
            return float(vote_str.replace('M', '')) * 1000000
        elif 'K' in vote_str:
            return float(vote_str.replace('K', '')) * 1000
    return float(vote_str)
df['Votes'] = df['Votes'].apply(convert_votes)

df['Votes'] = df['Votes'].fillna(df['Votes'].mean())

# %%
# df = df.drop(columns=['grossWorldWide', 'gross_US_Canada', 'opening_weekend_Gross'], axis=1)
# print(df.head())

# %%
# 'release_date', 'Movie Link' 제거

df = df.drop(columns=['release_date','Movie Link'])
print(df.head())
# Out:
#                                                Title  Year Duration    MPA  \
# 0    1. Star Wars: Episode III - Revenge of the Sith  2005   2h 20m  PG-13
# 1  2. The Chronicles of Narnia: The Lion, the Wit...  2005   2h 23m     PG
# 2             3. Harry Potter and the Goblet of Fire  2005   2h 37m  PG-13
# 3                               4. War of the Worlds  2005   1h 57m  PG-13
# 4                                       5. King Kong  2005    3h 7m  PG-13
#
#    Rating     Votes       budget  grossWorldWide  gross_US_Canada  \
# 0     7.6  867000.0  113000000.0     850035635.0      380270577.0
# 1     6.9  438000.0  180000000.0     745013115.0      291710957.0
# 2     7.7  705000.0  150000000.0     897468952.0      290469928.0
# 3     6.5  485000.0  132000000.0     603873504.0      234280354.0
# 4     7.2  455000.0  207000000.0     556906378.0      218080025.0
#
#    opening_weekend_Gross  ...  \
# 0            108435841.0  ...
# 1             65556312.0  ...
# 2            102685961.0  ...
# 3             64878725.0  ...
# 4             50130145.0  ...
#
#                                              writers  \
# 0                                   ['George Lucas']
# 1  ['Ann Peacock', 'Andrew Adamson', 'Christopher...
# 2                   ['Steve Kloves', 'J.K. Rowling']
# 3     ['Josh Friedman', 'David Koepp', 'H.G. Wells']
# 4  ['Fran Walsh', 'Philippa Boyens', 'Peter Jacks...
#
#                                                stars  \
# 0  ['Hayden Christensen', 'Natalie Portman', 'Ewa...
# 1  ['Tilda Swinton', 'Georgie Henley', 'William M...
# 2  ['Daniel Radcliffe', 'Emma Watson', 'Rupert Gr...
# 3    ['Tom Cruise', 'Dakota Fanning', 'Tim Robbins']
# 4      ['Naomi Watts', 'Jack Black', 'Adrien Brody']
#
#                                               genres  \
# 0  ['Action Epic', 'Adventure Epic', 'Dark Fantas...
# 1  ['Fantasy Epic', 'Supernatural Fantasy', 'Swor...
# 2  ['Sword & Sorcery', 'Teen Adventure', 'Teen Fa...
# 3  ['Action Epic', 'Adventure Epic', 'Alien Invas...
# 4  ['Adventure Epic', 'Dark Romance', 'Dinosaur A...
#
#                                     countries_origin  \
# 0  ['United States', 'Italy', 'Switzerland', 'Tha...
# 1                ['United Kingdom', 'United States']
# 2                ['United Kingdom', 'United States']
# 3                                  ['United States']
# 4        ['United States', 'New Zealand', 'Germany']
#
#                                    filming_locations  \
# 0             ['Mount Etna, Catania, Sicily, Italy']
# 1  ['Adrspach National Park, Trutnov, Czech Repub...
# 2  ['Glenfinnan Viaduct, Fort William, Highland, ...
# 3     ['JF Kennedy Blvd., Bayonne, New Jersey, USA']
# 4            ['Shelly Bay, Wellington, New Zealand']
#
#                                 production_companies  \
# 0  ['Lucasfilm', 'Mestiere Cinema', 'Pandora Films']
# 1           ['Walt Disney Pictures', 'Walden Media']
# 2  ['Warner Bros.', 'Heyday Films', 'Patalex Prod...
# 3  ['Paramount Pictures', 'Dreamworks Pictures', ...
# 4  ['Universal Pictures', 'WingNut Films', 'Big P...
#
#                                           Languages wins  nominations  oscars
# 0                                       ['English']    0           64       1
# 1  ['English', 'German', 'Brazilian Sign Language']    0           46       0
# 2                    ['English', 'French', 'Latin']    0           48       1
# 3                                       ['English']    0           49       3
# 4                                       ['English']    0          104       0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10700 entries, 0 to 599
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  10700 non-null  object
#  1   Year                   10700 non-null  int64
#  2   Duration               10672 non-null  object
#  3   MPA                    10700 non-null  object
#  4   Rating                 10700 non-null  float64
#  5   Votes                  10700 non-null  float64
#  6   budget                 4749 non-null   float64
#  7   grossWorldWide         9812 non-null   float64
#  8   gross_US_Canada        9394 non-null   float64
#  9   opening_weekend_Gross  8901 non-null   float64
#  10  directors              10700 non-null  object
#  11  writers                10700 non-null  object
#  12  stars                  10700 non-null  object
#  13  genres                 10700 non-null  object
#  14  countries_origin       10700 non-null  object
#  15  filming_locations      10700 non-null  object
#  16  production_companies   10700 non-null  object
#  17  Languages              10700 non-null  object
#  18  wins                   10700 non-null  int64
#  19  nominations            10700 non-null  int64
#  20  oscars                 10700 non-null  int64
# dtypes: float64(6), int64(4), object(11)
# memory usage: 1.8+ MB

# %%
gb = pd.read_csv('./data/genre_budget.csv')
gb
# Out:
#               genres        budget
# 0                NaN  0.000000e+00
# 1             Action  6.424403e+11
# 2        Action Epic  3.978353e+10
# 3    Adult Animation  8.553900e+08
# 4          Adventure  1.893925e+11
# ..               ...           ...
# 180        Whodunnit  1.280500e+09
# 181     Witch Horror  1.622000e+08
# 182  Workplace Drama  4.861992e+08
# 183            Wuxia  1.246632e+09
# 184    Zombie Horror  1.110070e+10
#
# [185 rows x 2 columns]

# %%
# 문자열 전처리

# 대괄호와 따옴표만 제거하고 쉼표는 그대로 두는 함수
def clean_column_values(column):
    return column.apply(lambda x: ', '.join([item.replace("'", "").replace('"', '').replace('[', '').replace(']', '') for item in str(x).split(',')]))

# 각 컬럼에 대해 전처리 수행
df_cleaned = df.apply(clean_column_values)

# 전처리된 데이터프레임 출력
print(df_cleaned)
# Out:
#                                                  Title  Year Duration  \
# 0      1. Star Wars: Episode III - Revenge of the Sith  2005   2h 20m
# 1    2. The Chronicles of Narnia: The Lion,  the Wi...  2005   2h 23m
# 2               3. Harry Potter and the Goblet of Fire  2005   2h 37m
# 3                                 4. War of the Worlds  2005   1h 57m
# 4                                         5. King Kong  2005    3h 7m
# ..                                                 ...   ...      ...
# 595                                     596. Vettaiyan  2024   2h 43m
# 596                                        597. Nr. 24  2024   1h 51m
# 597                                      598. Parallel  2024   1h 28m
# 598                               599. Fight or Flight  2024   2h 46m
# 599                                   600. A Sacrifice  2024   1h 34m
#
#          MPA Rating     Votes       budget grossWorldWide gross_US_Canada  \
# 0      PG-13    7.6  867000.0  113000000.0    850035635.0     380270577.0
# 1         PG    6.9  438000.0  180000000.0    745013115.0     291710957.0
# 2      PG-13    7.7  705000.0  150000000.0    897468952.0     290469928.0
# 3      PG-13    6.5  485000.0  132000000.0    603873504.0     234280354.0
# 4      PG-13    7.2  455000.0  207000000.0    556906378.0     218080025.0
# ..       ...    ...       ...          ...            ...             ...
# 595  unrated    7.1   38000.0          nan      2397623.0             nan
# 596  unrated    7.7    3400.0          nan      3301976.0             nan
# 597  unrated    5.3    1700.0          nan            nan             nan
# 598  unrated    7.0     117.0          nan            nan             nan
# 599        R    5.1    4300.0          nan       130017.0             nan
#
#     opening_weekend_Gross  ...  \
# 0             108435841.0  ...
# 1              65556312.0  ...
# 2             102685961.0  ...
# 3              64878725.0  ...
# 4              50130145.0  ...
# ..                    ...  ...
# 595                   nan  ...
# 596                   nan  ...
# 597                   nan  ...
# 598                   nan  ...
# 599                   nan  ...
#
#                                                writers  \
# 0                                         George Lucas
# 1    Ann Peacock,  Andrew Adamson,  Christopher Markus
# 2                          Steve Kloves,  J.K. Rowling
# 3             Josh Friedman,  David Koepp,  H.G. Wells
# 4         Fran Walsh,  Philippa Boyens,  Peter Jackson
# ..                                                 ...
# 595                                      T.J. Gnanavel
# 596         Erlend Loe,  Espen Lauritzen von Ibenfeldt
# 597        Aldis Hodge,  Edwin Hodge,  Jonathan Keasey
# 598                      Brooks McLaren,  D.J. Cotrona
# 599                       Jordan Scott,  Nicholas Hogg
#
#                                                  stars  \
# 0    Hayden Christensen,  Natalie Portman,  Ewan Mc...
# 1     Tilda Swinton,  Georgie Henley,  William Moseley
# 2        Daniel Radcliffe,  Emma Watson,  Rupert Grint
# 3            Tom Cruise,  Dakota Fanning,  Tim Robbins
# 4              Naomi Watts,  Jack Black,  Adrien Brody
# ..                                                 ...
# 595     Fahadh Faasil,  Amitabh Bachchan,  Rajinikanth
# 596  Mark Noble,  Lisa Loven Kongsli,  August Wittg...
# 597     Danielle Deadwyler,  Aldis Hodge,  Edwin Hodge
# 598  Josh Hartnett,  Katee Sackhoff,  Charithra Cha...
# 599              Eric Bana,  Sadie Sink,  Sylvia Hoeks
#
#                                                 genres  \
# 0    Action Epic,  Adventure Epic,  Dark Fantasy,  ...
# 1    Fantasy Epic,  Supernatural Fantasy,  Sword & ...
# 2    Sword & Sorcery,  Teen Adventure,  Teen Fantas...
# 3    Action Epic,  Adventure Epic,  Alien Invasion,...
# 4    Adventure Epic,  Dark Romance,  Dinosaur Adven...
# ..                                                 ...
# 595  Cop Drama,  One-Person Army Action,  Action,  ...
# 596  Docudrama,  Epic,  Period Drama,  Biography,  ...
# 597                          Drama,  Sci-Fi,  Thriller
# 598                                    Action,  Comedy
# 599                Drama,  Horror,  Mystery,  Thriller
#
#                                       countries_origin  \
# 0    United States,  Italy,  Switzerland,  Thailand...
# 1                       United Kingdom,  United States
# 2                       United Kingdom,  United States
# 3                                        United States
# 4                United States,  New Zealand,  Germany
# ..                                                 ...
# 595                                              India
# 596                                             Norway
# 597                                      United States
# 598                     United States,  United Kingdom
# 599  Germany,  United States,  United Kingdom,  France
#
#                                      filming_locations  \
# 0                Mount Etna,  Catania,  Sicily,  Italy
# 1    Adrspach National Park,  Trutnov,  Czech Republic
# 2    Glenfinnan Viaduct,  Fort William,  Highland, ...
# 3        JF Kennedy Blvd.,  Bayonne,  New Jersey,  USA
# 4                Shelly Bay,  Wellington,  New Zealand
# ..                                                 ...
# 595
# 596                             Rjukan,  Tinn,  Norway
# 597
# 598                                            Hungary
# 599
#
#                                   production_companies  \
# 0          Lucasfilm,  Mestiere Cinema,  Pandora Films
# 1                  Walt Disney Pictures,  Walden Media
# 2    Warner Bros.,  Heyday Films,  Patalex Productions
# 3    Paramount Pictures,  Dreamworks Pictures,  Amb...
# 4    Universal Pictures,  WingNut Films,  Big Prima...
# ..                                                 ...
# 595                                   Lyca Productions
# 596                   SF Norge A/S,  Motion Blur Films
# 597  Rumble Riot Pictures,  Hodge Brothers Producti...
# 598  Asbury Park Productions,  The Royal Budapest F...
# 599  Scott Free Productions,  Augenschein Filmprodu...
#
#                                       Languages wins nominations oscars
# 0                                       English    0          64      1
# 1    English,  German,  Brazilian Sign Language    0          46      0
# 2                      English,  French,  Latin    0          48      1
# 3                                       English    0          49      3
# 4                                       English    0         104      0
# ..                                          ...  ...         ...    ...
# 595                                       Tamil    0           0      0
# 596                                   Norwegian    0           0      0
# 597                                                0           0      0
# 598                                     English    0           0      0
# 599                            English,  German    0           0      0
#
# [10700 rows x 21 columns]

# %%
# gross 수익 결측치 처리

df[['grossWorldWide', 'gross_US_Canada', 'opening_weekend_Gross']] = df[['grossWorldWide', 'gross_US_Canada', 'opening_weekend_Gross']].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10700 entries, 0 to 599
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  10700 non-null  object
#  1   Year                   10700 non-null  int64
#  2   Duration               10672 non-null  object
#  3   MPA                    10700 non-null  object
#  4   Rating                 10700 non-null  float64
#  5   Votes                  10700 non-null  float64
#  6   budget                 4749 non-null   float64
#  7   grossWorldWide         10700 non-null  float64
#  8   gross_US_Canada        10700 non-null  float64
#  9   opening_weekend_Gross  10700 non-null  float64
#  10  directors              10700 non-null  object
#  11  writers                10700 non-null  object
#  12  stars                  10700 non-null  object
#  13  genres                 10700 non-null  object
#  14  countries_origin       10700 non-null  object
#  15  filming_locations      10700 non-null  object
#  16  production_companies   10700 non-null  object
#  17  Languages              10700 non-null  object
#  18  wins                   10700 non-null  int64
#  19  nominations            10700 non-null  int64
#  20  oscars                 10700 non-null  int64
# dtypes: float64(6), int64(4), object(11)
# memory usage: 1.8+ MB

# %%
import pandas as pd


# Duration 컬럼을 분(minute) 단위로 변환하는 함수
def str_to_minutes(duration):
    if pd.isnull(duration):
        return None  # None 값은 그대로 반환

    try:
        # 'h'가 포함된 경우, 시간과 분을 분으로 변환
        if 'h' in duration:
            duration = duration.split('h')
            hours = int(duration[0])  # 시간 값
            minutes = 0
            if 'm' in duration[1]:
                minutes = int(duration[1].split('m')[0])  # 분 값
            return hours * 60 + minutes  # 시간을 분으로 변환

        # 'm'만 있는 경우, 분 단위로 변환
        elif 'm' in duration:
            return int(duration.split('m')[0])  # 분 값만 추출

        # 숫자만 있는 경우 그대로 반환
        else:
            return int(duration)

    except Exception as e:
        return None  # 오류 발생 시 None 반환

# 'Duration' 컬럼에 str_to_minutes 함수 적용하여 분 단위로 변환
df['Duration'] = df['Duration'].apply(str_to_minutes)

# 'Duration' 컬럼을 int로 변환 (None 값은 NaN으로 대체)
df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')

# 'Duration'의 평균값을 구하고, null 값을 평균값으로 채우기
mean_duration = df['Duration'].mean()

# null 값에 평균값 채우기
df['Duration'] = df['Duration'].fillna(mean_duration)

# 결과 확인
print(df[['Duration']].head())
# Out:
#    Duration
# 0     140.0
# 1     143.0
# 2     157.0
# 3     117.0
# 4     187.0

# %%
df['budget'] = df['budget'].fillna(df.groupby('genres')['budget'].transform('mean'))

# %%
# 장르별 예산 결측치 처리
import pandas as pd

# 1단계: genre_budget.csv 파일을 불러옵니다.
genre_df = pd.read_csv('./data/genre_budget.csv')

# 2단계: 장르 그룹화 (비슷한 장르끼리 묶기)
genre_groups = {
    "Epic": ["Action Epic", "Fantasy Epic", "Adventure Epic", "War Epic", "Historical Epic", "Western Epic", "Romantic Epic"],
    "Fantasy": ["Fantasy", "Supernatural Fantasy", "Dark Fantasy", "Sword & Sorcery"],
    "Action": ["Action", "Car Action", "One-Person Army Action", "Martial Arts", "Gun Fu"],
    "Comedy": ["Comedy", "High-Concept Comedy", "Dark Comedy", "Slapstick", "Quirky Comedy", "Teen Comedy", "Raunchy Comedy", "Parody", "Screwball Comedy", "Stoner Comedy", "Body Swap Comedy"],
    "Horror": ["Horror", "Splatter Horror", "Slasher Horror", "Zombie Horror", "Monster Horror", "Vampire Horror", "Werewolf Horror", "Witch Horror", "Psychological Horror", "Body Horror", "Found Footage Horror", "Folk Horror", "B-Horror", "Kaiju"],
    "Romance": ["Romance", "Feel-Good Romance", "Holiday Romance", "Steamy Romance", "Tragic Romance", "Teen Romance", "Holiday Family", "Romantic Comedy"],
    "Adventure": ["Adventure", "Jungle Adventure", "Mountain Adventure", "Sea Adventure", "Desert Adventure", "Urban Adventure", "Globetrotting Adventure", "Teen Adventure"],
    "Drama": ["Drama", "Period Drama", "Legal Drama", "Crime Drama", "Medical Drama", "Political Drama", "Workplace Drama", "Teen Drama", "Psychological Drama", "Historical Drama", "Showbiz Drama", "Family Drama"]
}

# 3단계: 장르를 카테고리로 묶는 함수 정의
def categorize_genre(genre):
    for category, genres in genre_groups.items():
        print(genre)
        if genre in genres:
            return category
    return "Other"

# 4단계: 'genres' 열을 카테고리화하여 새로운 열 'genre_category'를 추가
genre_df['genre_category'] = genre_df['genres'].apply(categorize_genre)

# 5단계: 카테고리별 예산 합계와 평균 계산
category_budget = genre_df.groupby('genre_category')['budget'].agg(['sum', 'mean']).reset_index()

# 결과를 확인
print(category_budget)

# csv 파일로 만들기 
# category_budget.to_csv('data/category_budget.csv', index=False)

# null 값에 대입하기
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#
# Financial Drama
# Financial Drama
# Financial Drama
# Financial Drama
# Folk Horror
# Folk Horror
# Folk Horror
# Folk Horror
# Folk Horror
# Food Documentary
# Food Documentary
# Food Documentary
# Food Documentary
# Food Documentary
# Food Documentary
# Food Documentary
# Food Documentary
# Football
# Football
# Football
# Football
# Football
# Football
# Football
# Football
# Found Footage Horror
# Found Footage Horror
# Found Footage Horror
# Found Footage Horror
# Found Footage Horror
# Gangster
# Gangster
# Gangster
# Gangster
# Gangster
# Gangster
# Gangster
# Gangster
# Globetrotting Adventure
# Globetrotting Adventure
# Globetrotting Adventure
# Globetrotting Adventure
# Globetrotting Adventure
# Globetrotting Adventure
# Globetrotting Adventure
# Gun Fu
# Gun Fu
# Gun Fu
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hand-Drawn Animation
# Hard-boiled Detective
# Hard-boiled Detective
# Hard-boiled Detective
# Hard-boiled Detective
# Hard-boiled Detective
# Hard-boiled Detective
# Hard-boiled Detective
# Hard-boiled Detective
# Heist
# Heist
# Heist
# Heist
# Heist
# Heist
# Heist
# Heist
# High-Concept Comedy
# High-Concept Comedy
# High-Concept Comedy
# High-Concept Comedy
# Historical Epic
# History
# History
# History
# History
# History
# History
# History
# History
# History Documentary
# History Documentary
# History Documentary
# History Documentary
# History Documentary
# History Documentary
# History Documentary
# History Documentary
# Holiday
# Holiday
# Holiday
# Holiday
# Holiday
# Holiday
# Holiday
# Holiday
# Holiday Animation
# Holiday Animation
# Holiday Animation
# Holiday Animation
# Holiday Animation
# Holiday Animation
# Holiday Animation
# Holiday Animation
# Holiday Comedy
# Holiday Comedy
# Holiday Comedy
# Holiday Comedy
# Holiday Comedy
# Holiday Comedy
# Holiday Comedy
# Holiday Comedy
# Holiday Family
# Holiday Family
# Holiday Family
# Holiday Family
# Holiday Family
# Holiday Family
# Holiday Romance
# Holiday Romance
# Holiday Romance
# Holiday Romance
# Holiday Romance
# Holiday Romance
# Horror
# Horror
# Horror
# Horror
# Horror
# Isekai
# Isekai
# Isekai
# Isekai
# Isekai
# Isekai
# Isekai
# Isekai
# Iyashikei
# Iyashikei
# Iyashikei
# Iyashikei
# Iyashikei
# Iyashikei
# Iyashikei
# Iyashikei
# Jukebox Musical
# Jukebox Musical
# Jukebox Musical
# Jukebox Musical
# Jukebox Musical
# Jukebox Musical
# Jukebox Musical
# Jukebox Musical
# Jungle Adventure
# Jungle Adventure
# Jungle Adventure
# Jungle Adventure
# Jungle Adventure
# Jungle Adventure
# Jungle Adventure
# Kaiju
# Kaiju
# Kaiju
# Kaiju
# Kaiju
# Korean Drama
# Korean Drama
# Korean Drama
# Korean Drama
# Korean Drama
# Korean Drama
# Korean Drama
# Korean Drama
# Kung Fu
# Kung Fu
# Kung Fu
# Kung Fu
# Kung Fu
# Kung Fu
# Kung Fu
# Kung Fu
# Legal Drama
# Legal Drama
# Tragedy
# Tragedy
# Tragedy
# Tragedy
# Tragedy
# Tragedy
# Tragedy
# Tragic Romance
# Tragic Romance
# Tragic Romance
# Tragic Romance
# Tragic Romance
# Tragic Romance
# Travel Documentary
# Travel Documentary
# Travel Documentary
# Travel Documentary
# Travel Documentary
# Travel Documentary
# Travel Documentary
# Travel Documentary
# True Crime
# True Crime
# True Crime
# True Crime
# True Crime
# True Crime
# True Crime
# True Crime
# Urban Adventure
# Urban Adventure
# Urban Adventure
# Urban Adventure
# Urban Adventure
# Urban Adventure
# Urban Adventure
# Vampire Horror
# Vampire Horror
# Vampire Horror
# Vampire Horror
# Vampire Horror
# War
# War
# War
# War
# War
# War
# War
# War
# War Epic
# Water Sport
# Water Sport
# Water Sport
# Water Sport
# Water Sport
# Water Sport
# Water Sport
# Water Sport
# Werewolf Horror
# Werewolf Horror
# Werewolf Horror
# Werewolf Horror
# Werewolf Horror
# Western
# Western
# Western
# Western
# Western
# Western
# Western
# Western
# Western Epic
# Whodunnit
# Whodunnit
# Whodunnit
# Whodunnit
# Whodunnit
# Whodunnit
# Whodunnit
# Whodunnit
# Witch Horror
# Witch Horror
# Witch Horror
# Witch Horror
# Witch Horror
# Workplace Drama
# Workplace Drama
# Workplace Drama
# Workplace Drama
# Workplace Drama
# Workplace Drama
# Workplace Drama
# Workplace Drama
# Wuxia
# Wuxia
# Wuxia
# Wuxia
# Wuxia
# Wuxia
# Wuxia
# Wuxia
# Zombie Horror
# Zombie Horror
# Zombie Horror
# Zombie Horror
# Zombie Horror
#   genre_category           sum          mean
# 0         Action  7.033307e+11  1.406661e+11
# 1      Adventure  2.181856e+11  2.727319e+10
# 2         Comedy  9.423105e+10  8.566459e+09
# 3          Drama  3.687271e+11  4.096968e+10
# 4           Epic  6.995089e+10  9.992984e+09
# 5        Fantasy  1.718413e+11  4.296034e+10
# 6         Horror  1.253935e+11  8.956676e+09
# 7          Other  2.459579e+12  2.066873e+10
# 8        Romance  7.755940e+10  9.694925e+09

# %%
# 2단계: 장르 그룹화 (비슷한 장르끼리 묶기)
genre_groups = {
    "Epic": ["Action Epic", "Fantasy Epic", "Adventure Epic", "War Epic", "Historical Epic", "Western Epic", "Romantic Epic"],
    "Fantasy": ["Fantasy", "Supernatural Fantasy", "Dark Fantasy", "Sword & Sorcery"],
    "Action": ["Action", "Car Action", "One-Person Army Action", "Martial Arts", "Gun Fu"],
    "Comedy": ["Comedy", "High-Concept Comedy", "Dark Comedy", "Slapstick", "Quirky Comedy", "Teen Comedy", "Raunchy Comedy", "Parody", "Screwball Comedy", "Stoner Comedy", "Body Swap Comedy"],
    "Horror": ["Horror", "Splatter Horror", "Slasher Horror", "Zombie Horror", "Monster Horror", "Vampire Horror", "Werewolf Horror", "Witch Horror", "Psychological Horror", "Body Horror", "Found Footage Horror", "Folk Horror", "B-Horror", "Kaiju"],
    "Romance": ["Romance", "Feel-Good Romance", "Holiday Romance", "Steamy Romance", "Tragic Romance", "Teen Romance", "Holiday Family", "Romantic Comedy"],
    "Adventure": ["Adventure", "Jungle Adventure", "Mountain Adventure", "Sea Adventure", "Desert Adventure", "Urban Adventure", "Globetrotting Adventure", "Teen Adventure"],
    "Drama": ["Drama", "Period Drama", "Legal Drama", "Crime Drama", "Medical Drama", "Political Drama", "Workplace Drama", "Teen Drama", "Psychological Drama", "Historical Drama", "Showbiz Drama", "Family Drama"]
}

# 3단계: 장르를 카테고리로 묶는 함수 정의
def categorize_genre(genre: str):
    genre = genre.replace("'", "").replace('"', '').replace('[', '').replace(']', '')
    for category, genres in genre_groups.items():
        for g in genres:
            if g in genre:
                return category
        if category in genre:
            return category
    return "Other"
df['Category'] = df['genres'].apply(categorize_genre)

# %%
df['Category'].value_counts()
indices = df[df['budget'].isnull()].index

# %%
indices, len(indices)
# Out:
# (Index([106, 143, 147, 160, 194, 200, 203, 205, 206, 207,
#         ...
#         542, 543, 549, 572, 575, 578, 585, 592, 596, 597],
#        dtype='int64', length=1918),
#  1918)

# %%
## 카테고리별 예산 평균값을 구하고 null 값에 대입하기
df['budget'] = df['budget'].fillna(df['Category'].map(df.groupby('Category')['budget'].mean()))
# indices 값이 잘 들어갔는지 확인
df.loc[indices]
# Out:
#                            Title  Year  Duration      MPA  Rating     Votes  \
# 106            107. Ice Princess  2005      98.0        G     6.0   29000.0
# 106  107. My Super Ex-Girlfriend  2006      96.0    PG-13     5.2   68000.0
# 106           107. Reign Over Me  2007     124.0        R     7.4  101000.0
# 106                 107. Shutter  2008      85.0    PG-13     5.2   38000.0
# 106                    107. Nine  2009     118.0    PG-13     5.8   46000.0
# ..                           ...   ...       ...      ...     ...       ...
# 596                  597. Nr. 24  2024     111.0  unrated     7.7    3400.0
# 597     598. Performance Anxiety  2008      72.0  unrated     5.8      46.0
# 597           598. Then Came You  2020      97.0    PG-13     5.9    2700.0
# 597                598. Pamasahe  2022     104.0  unrated     5.3    1400.0
# 597                598. Parallel  2024      88.0  unrated     5.3    1700.0
#
#            budget  grossWorldWide  gross_US_Canada  opening_weekend_Gross  \
# 106  2.568496e+07      27645491.0       24402491.0              6807471.0
# 106  3.000000e+07      61108981.0       22530295.0              8603460.0
# 106  2.000000e+07      22242388.0       19661987.0              7460690.0
# 106  8.000000e+06      48555306.0       25928550.0             10447559.0
# 106  8.000000e+07      54004950.0       19676965.0               257232.0
# ..            ...             ...              ...                    ...
# 596  3.159483e+08       3301976.0              0.0                    0.0
# 597  1.000000e+04             0.0              0.0                    0.0
# 597  3.931164e+07             0.0              0.0                    0.0
# 597  1.482267e+07             0.0              0.0                    0.0
# 597  5.322545e+07             0.0              0.0                    0.0
#
#      ...                                              stars  \
# 106  ...  ['Michelle Trachtenberg', 'Kim Cattrall', 'Tre...
# 106  ...       ['Uma Thurman', 'Luke Wilson', 'Anna Faris']
# 106  ...  ['Adam Sandler', 'Don Cheadle', 'Jada Pinkett ...
# 106  ...  ['Joshua Jackson', 'Rachael Taylor', 'James Ky...
# 106  ...  ['Daniel Day-Lewis', 'Marion Cotillard', 'Pené...
# ..   ...                                                ...
# 596  ...  ['Mark Noble', 'Lisa Loven Kongsli', 'August W...
# 597  ...    ['Luke Mitchell', 'Joss Mars', "Wanda D'Parke"]
# 597  ...  ['Craig Ferguson', 'Kathie Lee Gifford', 'Ford...
# 597  ...  ['Azi Acosta', 'Mark Anthony Fernandez', 'Feli...
# 597  ...  ['Danielle Deadwyler', 'Aldis Hodge', 'Edwin H...
#
#                                                 genres  \
# 106  ['Teen Comedy', 'Comedy', 'Drama', 'Family', '...
# 106  ['Romantic Comedy', 'Comedy', 'Romance', 'Sci-...
# 106                           ['Dark Comedy', 'Drama']
# 106  ['Supernatural Horror', 'Horror', 'Mystery', '...
# 106                    ['Drama', 'Musical', 'Romance']
# ..                                                 ...
# 596  ['Docudrama', 'Epic', 'Period Drama', 'Biograp...
# 597            ['Comedy', 'Drama', 'Music', 'Romance']
# 597                     ['Comedy', 'Drama', 'Romance']
# 597                                          ['Drama']
# 597                    ['Drama', 'Sci-Fi', 'Thriller']
#
#                            countries_origin  \
# 106             ['Canada', 'United States']
# 106                       ['United States']
# 106                       ['United States']
# 106  ['Thailand', 'Japan', 'United States']
# 106     ['United Kingdom', 'United States']
# ..                                      ...
# 596                              ['Norway']
# 597                           ['Australia']
# 597                       ['United States']
# 597                         ['Philippines']
# 597                       ['United States']
#
#                                      filming_locations  \
# 106                       ['Toronto, Ontario, Canada']
# 106  ['Port Chester High School, Port Chester, New ...
# 106    ['Boyle Heights, Los Angeles, California, USA']
# 106                                   ['Tokyo, Japan']
# 106             ['Positano, Salerno, Campania, Italy']
# ..                                                 ...
# 596                           ['Rjukan, Tinn, Norway']
# 597                ['Brisbane, Queensland, Australia']
# 597  ['Ardkinglas House, Argyll and Bute, Scotland,...
# 597                                                 []
# 597                                                 []
#
#                                   production_companies  \
# 106  ['Walt Disney Pictures', 'Bridget Johnson Film...
# 106  ['New Regency Productions', 'Pariah', 'New Reg...
# 106  ['Relativity Media', 'Madison 23', 'Sunlight P...
# 106  ['New Regency Productions', 'New Regency Produ...
# 106  ['The Weinstein Company', 'Relativity Media', ...
# ..                                                 ...
# 596              ['SF Norge A/S', 'Motion Blur Films']
# 597               ['Artphotos', 'Dale Street Studios']
# 597  ['Love Me To Death', 'Whiskey & Wine', "Widow'...
# 597                                     ['Viva Films']
# 597  ['Rumble Riot Pictures', 'Hodge Brothers Produ...
#
#                             Languages wins nominations  oscars  Category
# 106                       ['English']    0           0       0    Comedy
# 106                       ['English']    0           0       0    Comedy
# 106                       ['English']    0           0       0    Comedy
# 106           ['English', 'Japanese']    0           0       0    Horror
# 106  ['English', 'Italian', 'French']    0          60       4   Romance
# ..                                ...  ...         ...     ...       ...
# 596                     ['Norwegian']    0           0       0      Epic
# 597                       ['English']    0           0       0    Comedy
# 597                       ['English']    0           0       0    Comedy
# 597           ['Tagalog', 'Filipino']    0           0       0     Drama
# 597                                []    0           0       0     Drama
#
# [36816 rows x 22 columns]
