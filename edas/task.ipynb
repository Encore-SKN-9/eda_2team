# %% [markdown]
# ### **페르소나**
#
# - **이름**: Alex Kim
# - **직업**: 영화 제작사 마케팅 팀장
# - **목표**: 시장 트렌드를 분석하여 관객들이 원하는 영화 장르와 특성을 파악하고, 투자 대비 수익성이 높은 영화 제작 아이디어를 도출하고자 함.
# - **관심사**:
#     - 어떤 영화가 최근 트렌드에 부합하는지?
#     - 흥행 성공 요인과 관련된 데이터 패턴 발견
#     - 관객들이 선호하는 장르, 러닝타임, 배우 등 구체적인 요소 분석
#     - 영화 제작 비용 대비 수익성을 극대화할 수 있는 전략

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from collections import Counter
from matplotlib import font_manager
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import FuncFormatter
import seaborn as sns

font_path = 'C:/Windows/Fonts/malgun.ttf'  # Windows의 맑은 고딕 폰트 경로
font_prop = font_manager.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()

df = pd.read_csv('./Data/preprocessed_movies_data.csv')
# 정보 확인

print(df.info())
print(df.head())
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10700 entries, 0 to 10699
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  10700 non-null  object
#  1   Year                   10700 non-null  int64
#  2   Duration               10700 non-null  float64
#  3   MPA                    10700 non-null  object
#  4   Rating                 10700 non-null  float64
#  5   Votes                  10700 non-null  float64
#  6   budget                 10700 non-null  float64
#  7   grossWorldWide         10700 non-null  float64
#  8   gross_US_Canada        10700 non-null  float64
#  9   opening_weekend_Gross  10700 non-null  float64
#  10  directors              10700 non-null  object
#  11  writers                10700 non-null  object
#  12  stars                  10700 non-null  object
#  13  genres                 10700 non-null  object
#  14  countries_origin       10700 non-null  object
#  15  filming_locations      10700 non-null  object
#  16  production_companies   10700 non-null  object
#  17  Languages              10700 non-null  object
#  18  nominations            10700 non-null  int64
#  19  oscars                 10700 non-null  int64
#  20  Category               10700 non-null  object
# dtypes: float64(7), int64(3), object(11)
# memory usage: 1.7+ MB
# None
#                                                Title  Year  Duration    MPA  \
# 0    1. Star Wars: Episode III - Revenge of the Sith  2005     140.0  PG-13
# 1  2. The Chronicles of Narnia: The Lion, the Wit...  2005     143.0     PG
# 2             3. Harry Potter and the Goblet of Fire  2005     157.0  PG-13
# 3                               4. War of the Worlds  2005     117.0  PG-13
# 4                                       5. King Kong  2005     187.0  PG-13
#
#    Rating     Votes       budget  grossWorldWide  gross_US_Canada  \
# 0     7.6  867000.0  113000000.0     850035635.0      380270577.0
# 1     6.9  438000.0  180000000.0     745013115.0      291710957.0
# 2     7.7  705000.0  150000000.0     897468952.0      290469928.0
# 3     6.5  485000.0  132000000.0     603873504.0      234280354.0
# 4     7.2  455000.0  207000000.0     556906378.0      218080025.0
#
#    opening_weekend_Gross  ...  \
# 0            108435841.0  ...
# 1             65556312.0  ...
# 2            102685961.0  ...
# 3             64878725.0  ...
# 4             50130145.0  ...
#
#                                              writers  \
# 0                                   ['George Lucas']
# 1  ['Ann Peacock', 'Andrew Adamson', 'Christopher...
# 2                   ['Steve Kloves', 'J.K. Rowling']
# 3     ['Josh Friedman', 'David Koepp', 'H.G. Wells']
# 4  ['Fran Walsh', 'Philippa Boyens', 'Peter Jacks...
#
#                                                stars  \
# 0  ['Hayden Christensen', 'Natalie Portman', 'Ewa...
# 1  ['Tilda Swinton', 'Georgie Henley', 'William M...
# 2  ['Daniel Radcliffe', 'Emma Watson', 'Rupert Gr...
# 3    ['Tom Cruise', 'Dakota Fanning', 'Tim Robbins']
# 4      ['Naomi Watts', 'Jack Black', 'Adrien Brody']
#
#                                               genres  \
# 0  ['Action Epic', 'Adventure Epic', 'Dark Fantas...
# 1  ['Fantasy Epic', 'Supernatural Fantasy', 'Swor...
# 2  ['Sword & Sorcery', 'Teen Adventure', 'Teen Fa...
# 3  ['Action Epic', 'Adventure Epic', 'Alien Invas...
# 4  ['Adventure Epic', 'Dark Romance', 'Dinosaur A...
#
#                                     countries_origin  \
# 0  ['United States', 'Italy', 'Switzerland', 'Tha...
# 1                ['United Kingdom', 'United States']
# 2                ['United Kingdom', 'United States']
# 3                                  ['United States']
# 4        ['United States', 'New Zealand', 'Germany']
#
#                                    filming_locations  \
# 0             ['Mount Etna, Catania, Sicily, Italy']
# 1  ['Adrspach National Park, Trutnov, Czech Repub...
# 2  ['Glenfinnan Viaduct, Fort William, Highland, ...
# 3     ['JF Kennedy Blvd., Bayonne, New Jersey, USA']
# 4            ['Shelly Bay, Wellington, New Zealand']
#
#                                 production_companies  \
# 0  ['Lucasfilm', 'Mestiere Cinema', 'Pandora Films']
# 1           ['Walt Disney Pictures', 'Walden Media']
# 2  ['Warner Bros.', 'Heyday Films', 'Patalex Prod...
# 3  ['Paramount Pictures', 'Dreamworks Pictures', ...
# 4  ['Universal Pictures', 'WingNut Films', 'Big P...
#
#                                           Languages nominations  oscars  \
# 0                                       ['English']          64       1
# 1  ['English', 'German', 'Brazilian Sign Language']          46       0
# 2                    ['English', 'French', 'Latin']          48       1
# 3                                       ['English']          49       3
# 4                                       ['English']         104       0
#
#    Category
# 0      Epic
# 1      Epic
# 2   Fantasy
# 3      Epic
# 4      Epic
#
# [5 rows x 21 columns]
# Index(['Title', 'Year', 'Duration', 'MPA', 'Rating', 'Votes', 'budget',
#        'grossWorldWide', 'gross_US_Canada', 'opening_weekend_Gross',
#        'directors', 'writers', 'stars', 'genres', 'countries_origin',
#        'filming_locations', 'production_companies', 'Languages', 'nominations',
#        'oscars', 'Category'],
#       dtype='object')

# %% [markdown]
# ### **1. 시장 트렌드 분석**
#
# - 최근 몇 년간 가장 높은 수익을 올린 영화 장르는 무엇인가요?
# - 연도별 IMDb 평점 상위 영화들의 특징(장르, 러닝타임, 주요 배우)은 무엇인가요?
# - 특정 장르의 영화 흥행 여부(수익성)는 어떻게 변화했나요?
# - 영화 상영 시간(Duration)이 관객 선호도(Rating)와 어떤 관계를 가지나요?

# %%
# 1. 

# 연도별로 장르 별 총 수익 계산산
genre_earnings = df.groupby(['Year','Category'])['grossWorldWide'].sum().reset_index()

# 최신 연도 찾기 
lastest_year = genre_earnings['Year'].max()

# 최신 연도에서 가장 높은 수익을 올린 영화 장르 추출
recent_earnings =genre_earnings[genre_earnings['Year']==lastest_year]

# 최근 연도에서 장르별 총 수익 추출
top_10_genres = recent_earnings.sort_values('grossWorldWide', ascending=False).head(10)


print(top_10_genres)
# Out:
#      Year   Category  grossWorldWide
# 176  2024    Fantasy    4.350808e+09
# 173  2024     Comedy    3.483058e+09
# 171  2024     Action    3.353946e+09
# 175  2024       Epic    3.179026e+09
# 177  2024     Horror    1.557896e+09
# 174  2024      Drama    8.977298e+08
# 179  2024    Romance    4.598866e+08
# 178  2024      Other    4.366186e+08
# 172  2024  Adventure    6.291574e+07

# %%
# 2.
top_movies = df.loc[df.groupby('Year')['Rating'].idxmax()]

# 상위 영화들의 장르, 러닝타임, 주요 배우를 추출
top_movies_characters = top_movies[['Year', 'Title', 'Category', 'Duration', 'Rating', 'stars']]

# 결과 확인
print(top_movies_characters)
# Out:
#        Year                                              Title Category  \
# 491    2005           492. Sacred Stage: The Mariinsky Theater    Other
# 921    2006                           422. Dare Not Walk Alone    Other
# 1138   2007                                         139. U2 3D    Other
# 1550   2008                                 1. The Dark Knight     Epic
# 2527   2009                       378. The Legend of Pale Male    Other
# 2705   2010                                       6. Inception     Epic
# 3339   2011                              140. The Intouchables    Other
# 4189   2012                          490. This Binary Universe    Other
# 4227   2013                        28. The Wolf of Wall Street     Epic
# 5128   2014                                 379. Veil of Tears    Drama
# 5500   2015                                        251. Hamlet    Drama
# 6096   2016                               347. Apparition Hill    Other
# 6736   2017  487. PGS: Intuition Is Your Personal Guidance ...    Other
# 7296   2018                                     497. Twiceland    Other
# 7828   2019                              529. Love Goes Public    Other
# 7943   2020                               94. Chal Mera Putt 2    Drama
# 8620   2021                             171. Ends of the Earth    Other
# 9363   2022                                 414. Remember This    Drama
# 9959   2023                       410. Day by Day: The Dynasty    Other
# 10340  2024                                 241. Water Brother    Other
#
#          Duration  Rating                                              stars
# 491     61.000000     8.8  ['Valery Gergiev', 'Yulia Makhalina', 'Richard...
# 921     83.000000     8.8                                   ['Unknown Cast']
# 1138    85.000000     8.4               ['Bono', 'Adam Clayton', 'The Edge']
# 1550   152.000000     9.0  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 2527    85.000000     9.2  ['Alexander Fisher', 'Lincoln Karim', 'Charles...
# 2705   148.000000     8.8  ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', ...
# 3339   112.000000     8.5                                   ['Unknown Cast']
# 4189   107.000000     8.8                                   ['Unknown Cast']
# 4227   180.000000     8.2  ['Leonardo DiCaprio', 'Jonah Hill', 'Margot Ro...
# 5128    90.000000     8.8  ['Natalie Grant', 'K.P. Yohannan', 'Daniel Joh...
# 5500   217.000000     8.4  ['Benedict Cumberbatch', 'Ciarán Hinds', 'Sian...
# 6096   115.000000     8.8                                   ['Unknown Cast']
# 6736    83.000000     8.9  ['Caroline Myss', 'James Van Praagh', 'Lee Car...
# 7296   110.000000     9.3          ['Im Nayeon', 'Myoui Mina', 'Hirai Momo']
# 7828    68.000000     9.6                                   ['Unknown Cast']
# 7943   124.000000     8.8  ['Amrinder Gill', 'Simi Chahal', 'Nasir Chinyo...
# 8620    84.000000     9.2                       ['Mark Jobe', 'David Platt']
# 9363    95.000000     9.1                               ['David Strathairn']
# 9959   129.000000     9.6                                   ['Unknown Cast']
# 10340  106.090278     9.5                      ['Tony Hawk', 'Sid Abbruzzi']

# %%
# 3.
genre_earnings = df.groupby(['Year', 'Category'])['grossWorldWide'].sum().reset_index()

# 모든 장르에 대해 시각화
plt.figure(figsize=(14, 8))  # 넓은 형태의 그림 크기 지정

# 각 장르에 대해 연도별 수익을 시각화
for genre in genre_earnings['Category'].unique():
    genre_data = genre_earnings[genre_earnings['Category'] == genre]
    plt.plot(genre_data['Year'], genre_data['grossWorldWide'], marker='o', label=genre)

plt.xlabel('Year')
plt.ylabel('Gross Worldwide Earnings ($)')
plt.title('Worldwide Earnings of Movies by Genre Over the Years')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')  # 범례를 오른쪽에 배치
plt.grid(True)
plt.xticks(rotation=45)  # 연도 표시가 겹치지 않도록 회전
plt.tight_layout()  # 레이아웃 자동 조정
plt.show()

# %%
# 4. 

# 'Duration'과 'Rating'의 관계를 시각화 (산점도)
plt.figure(figsize=(10, 6))
plt.scatter(df['Duration'], df['Rating'], alpha=0.5)
plt.xlabel('Movie Duration (minutes)')
plt.ylabel('IMDb Rating')
plt.title('Movie Duration vs IMDb Rating')
plt.grid(True)
plt.show()

#'Duration'과 'Rating'의 상관계수 계산
correlation = df['Duration'].corr(df['Rating'])
print(f"Correlation between Duration and Rating: {correlation:.2f}")


# 만약 값이 1에 가까우면 상영 시간이 길어질수록 평점이 높아지는 경향이 있음을 의미하며, 
# -1에 가까우면 반대로 상영 시간이 길어질수록 평점이 낮아지는 경향이 있음을 나타냅니다. 
# 0에 가까운 값은 두 변수 간에 관계가 없다는 것을 의미합니다.
# Out:
# Correlation between Duration and Rating: 0.14

# %% [markdown]
# ### **2. 흥행 요소 분석**
#
# - 높은 수익을 낸 영화의 공통적인 요소(감독, 작가, 주연배우)는 무엇인가요?
# - IMDb 평점(Rating)과 투표 수(Votes) 간 상관관계는 어떤가요?
# - 개봉 주 수익(Opening_weekend_Gross)이 전체 흥행(GrossWorldwide)과 어떤 연관이 있나요?

# %%
# 1. 

# 상위 10개 영화 추출 (가장 높은 수익을 낸 영화 10개)
top_10_movies = df.nlargest(10, 'grossWorldWide')

# 감독, 작가, 주연배우 정보 확인
top_10_movies_elements = top_10_movies[['Title', 'directors', 'writers', 'stars', 'grossWorldWide']]

# 1. 감독, 작가, 주연배우를 분리하여 리스트로 만들어 빈도수 분석
directors_list = []
writers_list = []
stars_list = []

for index, row in top_10_movies.iterrows():
    # 감독, 작가, 주연배우를 분리하여 추가
    if isinstance(row['directors'], str):
        directors_list.extend(row['directors'].split(','))
    if isinstance(row['writers'], str):
        writers_list.extend(row['writers'].split(','))
    if isinstance(row['stars'], str):
        stars_list.extend(row['stars'].split(','))

# 2. 빈도수 분석 (Counter 사용)
directors_count = Counter([director.strip() for director in directors_list])
writers_count = Counter([writer.strip() for writer in writers_list])
stars_count = Counter([star.strip() for star in stars_list])

# 3. 상위 5명의 감독, 작가, 주연배우 확인
top_directors = directors_count.most_common(5)
top_writers = writers_count.most_common(5)
top_stars = stars_count.most_common(5)

# 결과 출력
print("Top 10 Movies with Highest Gross Worldwide Earnings:")
print(top_10_movies_elements[['Title', 'directors', 'writers', 'stars', 'grossWorldWide']])

print("\nTop 5 Most Common Directors:")
for director, count in top_directors:
    print(f"{director}: {count}")

print("\nTop 5 Most Common Writers:")
for writer, count in top_writers:
    print(f"{writer}: {count}")

print("\nTop 5 Most Common Stars:")
for star, count in top_stars:
    print(f"{star}: {count}")
# Out:
# Top 10 Movies with Highest Gross Worldwide Earnings:
#                                                Title  \
# 2150                                       1. Avatar
# 7300                            1. Avengers: Endgame
# 8951                     2. Avatar: The Way of Water
# 5250   1. Star Wars: Episode VII - The Force Awakens
# 6801                       2. Avengers: Infinity War
# 8450                      1. Spider-Man: No Way Home
# 10100                                1. Inside Out 2
# 5251                               2. Jurassic World
# 7301                                2. The Lion King
# 3700                                 1. The Avengers
#
#                             directors  \
# 2150                ['James Cameron']
# 7300   ['Anthony Russo', 'Joe Russo']
# 8951                ['James Cameron']
# 5250                  ['J.J. Abrams']
# 6801   ['Anthony Russo', 'Joe Russo']
# 8450                    ['Jon Watts']
# 10100                 ['Kelsey Mann']
# 5251              ['Colin Trevorrow']
# 7301                  ['Jon Favreau']
# 3700                  ['Joss Whedon']
#
#                                                  writers  \
# 2150                                   ['James Cameron']
# 7300   ['Christopher Markus', 'Stephen McFeely', 'Sta...
# 8951    ['James Cameron', 'Rick Jaffa', 'Amanda Silver']
# 5250   ['Lawrence Kasdan', 'J.J. Abrams', 'Michael Ar...
# 6801   ['Christopher Markus', 'Stephen McFeely', 'Sta...
# 8450       ['Chris McKenna', 'Erik Sommers', 'Stan Lee']
# 10100    ['Meg LeFauve', 'Dave Holstein', 'Kelsey Mann']
# 5251   ['Rick Jaffa', 'Amanda Silver', 'Colin Trevorr...
# 7301   ['Jeff Nathanson', 'Irene Mecchi', 'Jonathan R...
# 3700                         ['Joss Whedon', 'Zak Penn']
#
#                                                    stars  grossWorldWide
# 2150   ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...    2.923706e+09
# 7300   ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...    2.799439e+09
# 8951   ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...    2.320250e+09
# 5250      ['Daisy Ridley', 'John Boyega', 'Oscar Isaac']    2.071310e+09
# 6801   ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...    2.052415e+09
# 8450   ['Tom Holland', 'Zendaya', 'Benedict Cumberbat...    1.952724e+09
# 10100  ['Amy Poehler', 'Maya Hawke', 'Kensington Tall...    1.698773e+09
# 5251   ['Chris Pratt', 'Bryce Dallas Howard', 'Ty Sim...    1.671537e+09
# 7301          ['Donald Glover', 'Beyoncé', 'Seth Rogen']    1.662021e+09
# 3700   ['Robert Downey Jr.', 'Chris Evans', 'Scarlett...    1.520539e+09
#
# Top 5 Most Common Directors:
# ['James Cameron']: 2
# ['Anthony Russo': 2
# 'Joe Russo']: 2
# ['J.J. Abrams']: 1
# ['Jon Watts']: 1
#
# Top 5 Most Common Writers:
# 'Stan Lee']: 3
# ['Christopher Markus': 2
# 'Stephen McFeely': 2
# ['James Cameron']: 1
# ['James Cameron': 1
#
# Top 5 Most Common Stars:
# ['Robert Downey Jr.': 3
# ['Sam Worthington': 2
# 'Zoe Saldana': 2
# 'Sigourney Weaver']: 2
# 'Chris Evans': 2

# %%
# 2.

correlation = df['Rating'].corr(df['Votes'])

# 결과 출력
print(f"평점과 투표수의 상관관계: {correlation:.2f}")
# Out:
# 평점과 투표수의 상관관계: 0.22

# %%
# 'opening_weekend_Gross'와 'grossWorldWide' 컬럼을 숫자형으로 변환
df['opening_weekend_Gross'] = pd.to_numeric(df['opening_weekend_Gross'], errors='coerce')

# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df['opening_weekend_Gross'], df['grossWorldWide'], alpha=0.5)

# 천 단위 구분 및 통화 기호 추가 함수
def currency(x, pos):
    return f"${x:,.0f}"

# X축과 Y축에 천 단위 구분과 통화 기호 적용
plt.gca().xaxis.set_major_formatter(FuncFormatter(currency))
plt.gca().yaxis.set_major_formatter(FuncFormatter(currency))

# 축 레이블 및 제목 설정
plt.xlabel('Opening Weekend Gross ($)')
plt.ylabel('Gross Worldwide Earnings ($)')
plt.title('Opening Weekend Gross vs Gross Worldwide Earnings')

plt.grid(True)

# 그래프 출력
plt.tight_layout()
plt.show()

# 'opening_weekend_Gross'와 'grossWorldWide'의 상관 계수 계산
opening_weekend_correlation = df['opening_weekend_Gross'].corr(df['grossWorldWide'])
print(f"개봉 주 수익(Opening_weekend_Gross)이 전체 흥행(GrossWorldwide) 상관 관계 : {opening_weekend_correlation:.2f}")
# Out:
# 개봉 주 수익(Opening_weekend_Gross)이 전체 흥행(GrossWorldwide) 상관 관계 : 0.90

# %% [markdown]
# ### **3. 관객 선호도 분석**
#
# - 특정 MPA 등급(e.g., PG, R)에 따른 관객 선호도(Rating) 차이가 있나요?
# - 상위 평점 영화들의 주요 언어(Languages)는 무엇인가요?
# - 영화 촬영지(Filming_locations)가 흥행 성과에 미치는 영향은 무엇인가요?

# %%
# 1. 특정 MPA 등급에 따른 관객 선호도(Rating) 차이
mpa_avg_rating = df.groupby('MPA')['Rating'].mean().reset_index()

# 출력: MPA 등급별 평균 Rating 확인
print("MPA 등급별 평균 Rating:")
print(mpa_avg_rating)
# Out:
# MPA 등급별 평균 Rating:
#           MPA    Rating
# 0         13+  6.066667
# 1         16+  6.175000
# 2         18+  5.966667
# 3    Approved  7.733333
# 4           G  6.407216
# 5           M  7.300000
# 6       MA-17  7.200000
# 7       NC-17  6.345455
# 8   Not Rated  6.407627
# 9          PG  6.312344
# 10      PG-13  6.303789
# 11          R  6.290678
# 12      TV-14  6.386087
# 13       TV-G  6.520000
# 14      TV-MA  6.243787
# 15      TV-PG  6.463768
# 16       TV-Y  6.300000
# 17      TV-Y7  6.120000
# 18   TV-Y7-FV  7.100000
# 19    Unrated  6.632967

# %%
# 2. 상위 평점 영화들의 주요 언어(Languages)
# IMDb 평점이 상위 10개 영화 추출
top_rated_movies = df.nlargest(10, 'Rating')

# 상위 평점 영화들의 주요 언어(Languages) 분석
top_rated_languages = top_rated_movies['Languages'].value_counts().reset_index()
top_rated_languages.columns = ['Language', 'Count']

# 출력: 상위 평점 영화들의 주요 언어
print("\n상위 평점 영화들의 주요 언어:")
print(top_rated_languages)
# Out:
# 상위 평점 영화들의 주요 언어:
#                Language  Count
# 0           ['English']      6
# 1            ['Korean']      2
# 2  ['Unknown Language']      1
# 3          ['Japanese']      1

# %%
# 3. 영화 촬영지(Filming_locations)가 흥행 성과에 미치는 영향
# 'Filming_locations'에 대한 영화의 평균 'grossWorldWide' 수익
filming_location_avg_earnings = df.groupby('filming_locations')['grossWorldWide'].mean().reset_index()

filming_location_avg_earnings_sorted = filming_location_avg_earnings.sort_values(by='grossWorldWide', ascending=False).reset_index(drop=True)

# 출력: 촬영지별 평균 'grossWorldWide' 수익
print("\n영화 촬영지별 평균 흥행 성과:")
print(filming_location_avg_earnings_sorted.head(5))
# Out:
# 영화 촬영지별 평균 흥행 성과:
#                                    filming_locations  grossWorldWide
# 0  ['Durham Cathedral, The College, Durham, Count...    2.799439e+09
# 1  ['Stone Street Studios, Wellington, New Zealand']    2.320250e+09
# 2         ['Skellig Michael, County Kerry, Ireland']    2.071310e+09
# 3  ['Cockburn Street, Edinburgh, City of Edinburg...    2.052415e+09
# 4  ["Kualoa Ranch - 49560 Kamehameha Highway, Ka'...    1.671537e+09

# %% [markdown]
# ### **4. 지역별 분석**
#
# - 북미(North America) 흥행 수익(Gross_US_Canada)과 글로벌 흥행 수익(GrossWorldwide) 간 비율은 어떻게 되나요?
# - 제작 국가(Countries_origin)에 따른 흥행 성과는 어떤 차이가 있나요?
# - 특정 국가나 언어에서 제작된 영화가 글로벌 흥행(GrossWorldwide)에서 차지하는 비율은?

# %%
df['north_america_ratio'] = df['gross_US_Canada'] / df['grossWorldWide']
print("\n북미 흥행 수익과 글로벌 흥행 수익 간의 비율:")
print(df[['Title', 'north_america_ratio']].head())
# Out:
# 북미 흥행 수익과 글로벌 흥행 수익 간의 비율:
#                                                Title  north_america_ratio
# 0    1. Star Wars: Episode III - Revenge of the Sith             0.447358
# 1  2. The Chronicles of Narnia: The Lion, the Wit...             0.391551
# 2             3. Harry Potter and the Goblet of Fire             0.323655
# 3                               4. War of the Worlds             0.387963
# 4                                       5. King Kong             0.391592

# %%
# 2. 제작 국가(Countries_origin)에 따른 흥행 성과 분석

# 국가별 평균 글로벌 수익 계산
country_avg_earnings = df.groupby('countries_origin')['grossWorldWide'].mean().reset_index()

# 상위 10개 국가 출력 (글로벌 수익 순)
country_avg_earnings_sorted = country_avg_earnings.sort_values(by='grossWorldWide', ascending=False).head(10)
print("\n제작 국가별 평균 글로벌 수익:")
print(country_avg_earnings_sorted)
# Out:
# 제작 국가별 평균 글로벌 수익:
#                                        countries_origin  grossWorldWide
# 1730       ['United States', 'United Kingdom', 'Kenya']    1.662021e+09
# 1406  ['United States', 'China', 'Japan', 'Canada', ...    1.515342e+09
# 1735  ['United States', 'United Kingdom', 'New Zeala...    1.338074e+09
# 1483        ['United States', 'Germany', 'Puerto Rico']    1.155046e+09
# 1421  ['United States', 'Czech Republic', 'Australia...    1.132705e+09
# 1504  ['United States', 'Hong Kong', 'Cambodia', 'Un...    1.123794e+09
# 1742  ['United States', 'United Kingdom', 'Singapore...    1.054304e+09
# 1623                        ['United States', 'Norway']    1.053709e+09
# 1455               ['United States', 'France', 'Japan']    1.034800e+09
# 1551  ['United States', 'Italy', 'Canada', 'Japan', ...    1.025468e+09

# %%
df['grossWorldWide'] = pd.to_numeric(df['grossWorldWide'], errors='coerce')

# 전체 글로벌 수익 계산
total_global_earnings = df['grossWorldWide'].sum()

# 국가별 글로벌 수익 비율 계산
country_earnings_percentage = {}

# 각 영화에 대해 반복문을 사용하여 국가별 수익 합산
for index, row in df.iterrows():
    countries_list = [country.strip() for country in str(row['countries_origin']).split(',')]

    for country in countries_list:
        # 국가별 수익 합산
        if country not in country_earnings_percentage:
            country_earnings_percentage[country] = 0
        country_earnings_percentage[country] += row['grossWorldWide']

# 각 국가별 글로벌 수익 비율 계산
country_earnings_percentage = {country: (earnings / total_global_earnings) * 100 
                               for country, earnings in country_earnings_percentage.items()}

# 결과 출력
print("\n각 국가가 글로벌 흥행에서 차지하는 비율:")
for country, percentage in country_earnings_percentage.items():
    print(f"{country}: {percentage:.2f}%")

# 시각화
plt.figure(figsize=(12, 8))  # 그래프 크기 설정
plt.bar(country_earnings_percentage.keys(), country_earnings_percentage.values(), color='skyblue')

# x축 레이블 회전 (이름 겹침 방지)
plt.xticks(rotation=90)

# 제목과 레이블 설정
plt.title('각 국가가 글로벌 흥행에서 차지하는 비율', fontsize=16)
plt.xlabel('국가', fontsize=12)
plt.ylabel('비율 (%)', fontsize=12)

# 그래프 출력
plt.tight_layout()  # 레이블 겹침 방지
plt.show()
# Out:
# 각 국가가 글로벌 흥행에서 차지하는 비율:
# ['United States': 40.29%
# 'Italy': 1.55%
# 'Switzerland': 0.26%
# 'Thailand': 0.72%
# 'United Kingdom']: 9.62%
# ['United Kingdom': 8.24%
# 'United States']: 10.42%
# ['United States']: 34.85%
# 'New Zealand': 1.75%
# 'Germany']: 1.94%
# 'Canada': 7.64%
# ['Germany': 1.15%
# ['Canada': 1.19%
# 'Canada']: 8.78%
# ['France': 1.29%
# 'France': 3.30%
# 'Germany': 2.94%
# 'United Kingdom': 6.97%
# 'Spain': 1.11%
# ['Serbia and Montenegro': 0.02%
# 'United Arab Emirates']: 0.50%
# 'France']: 2.46%
# 'Morocco': 0.70%
# 'United States': 4.03%
# 'Czech Republic']: 0.10%
# 'Australia': 2.67%
# ['Czech Republic': 0.13%
# 'Kenya': 0.02%
# 'Switzerland']: 0.09%
# ['Australia': 0.59%
# 'Japan': 2.80%
# 'Czech Republic': 1.05%
# ['United Kingdom']: 0.13%
# 'Brazil': 0.12%
# 'Italy']: 1.15%
# ['Switzerland': 0.07%
# 'Luxembourg': 0.06%
# 'Pakistan']: 0.01%
# 'Romania': 0.05%
# ['Australia']: 0.04%
# ['Thailand': 0.02%
# 'Hong Kong': 1.30%
# 'Australia']: 2.56%
# 'India']: 1.75%
# ['New Zealand': 0.43%
# 'Mexico': 0.62%
# 'Austria': 0.45%
# 'South Africa']: 0.05%
# ['Mexico']: 0.06%
# 'China': 4.29%
# 'Isle of Man': 0.00%
# ['Occupied Palestinian Territory': 0.00%
# 'Netherlands': 0.22%
# 'Israel': 0.01%
# 'Denmark': 0.56%
# ['India': 0.22%
# ['India']: 1.07%
# 'Dominican Republic']: 0.01%
# 'Belgium': 0.40%
# 'Japan']: 4.64%
# ['France']: 0.31%
# 'Belgium']: 0.47%
# ['Canada']: 0.02%
# ['Ireland': 0.18%
# ['Norway': 0.02%
# ['Germany']: 0.03%
# ['China': 1.42%
# 'South Korea': 0.44%
# 'Ireland': 0.16%
# ['Belgium': 0.06%
# ['Russia']: 0.04%
# ['Brazil']: 0.03%
# 'Mexico']: 0.84%
# ['Japan']: 1.01%
# ['Philippines']: 0.01%
# 'Hong Kong']: 2.37%
# ['South Korea']: 1.01%
# ['Hungary': 0.06%
# ['Argentina': 0.03%
# 'Spain']: 0.54%
# 'Taiwan']: 0.03%
# 'Mongolia']: 0.00%
# ['Spain': 0.25%
# ['Brazil': 0.03%
# ['Tunisia': 0.00%
# 'Hungary': 0.65%
# 'Iran': 0.00%
# ['Romania']: 0.00%
# ['Kazakhstan': 0.00%
# ['Denmark': 0.08%
# 'Sweden': 0.18%
# ['Russia': 0.03%
# ['China']: 3.16%
# ['Mexico': 0.14%
# 'Turkey']: 0.06%
# ['Philippines': 0.00%
# 'Iceland': 0.37%
# 'Greece']: 0.01%
# 'Slovakia']: 0.08%
# 'Cameroon']: 0.00%
# 'China']: 3.36%
# ['Israel': 0.01%
# ['Spain']: 0.05%
# ['Italy': 0.11%
# ['Iran']: 0.00%
# ['Portugal']: 0.00%
# ['Argentina']: 0.00%
# ['Hong Kong': 0.40%
# 'Netherlands']: 0.26%
# ['Netherlands']: 0.00%
# ['Israel']: 0.00%
# 'Ireland']: 0.11%
# ['Belgium']: 0.00%
# 'Bolivia']: 0.00%
# ['Italy']: 0.02%
# ['Uruguay']: 0.00%
# ['Puerto Rico']: 0.00%
# ['Denmark']: 0.01%
# 'Argentina': 0.01%
# ['Luxembourg': 0.00%
# ['New Zealand']: 0.02%
# 'Malta': 0.24%
# 'Bulgaria']: 0.23%
# 'Bahamas']: 0.13%
# 'Hungary']: 0.56%
# 'Paraguay': 0.04%
# 'Uruguay']: 0.04%
# 'Taiwan': 0.33%
# 'Philippines': 0.08%
# 'South Korea']: 0.34%
# 'Morocco']: 0.23%
# ['South Africa': 0.05%
# 'Liechtenstein': 0.00%
# ['Netherlands': 0.02%
# 'Romania']: 0.02%
# 'South Africa': 0.16%
# 'Isle of Man']: 0.01%
# ['South Korea': 0.12%
# 'Norway']: 0.75%
# 'Poland': 0.12%
# ['Poland': 0.02%
# ['Norway']: 0.01%
# 'Estonia']: 0.00%
# ['Algeria': 0.01%
# 'Greece': 0.01%
# 'Greenland']: 0.00%
# ['Switzerland']: 0.00%
# 'Cambodia']: 0.01%
# 'Denmark']: 0.14%
# ['Bhutan']: 0.00%
# ['Turkey': 0.00%
# 'Mali': 0.00%
# ['Austria': 0.01%
# 'Portugal']: 0.02%
# 'Luxembourg']: 0.03%
# ['Hong Kong']: 0.04%
# ['Chile']: 0.00%
# ['Thailand']: 0.00%
# 'Iceland']: 0.17%
# ['Bosnia and Herzegovina': 0.00%
# 'Croatia': 0.03%
# ['Colombia': 0.00%
# 'Thailand']: 0.10%
# ['Czech Republic']: 0.00%
# ['Malaysia': 0.00%
# 'Austria']: 0.02%
# 'North Korea': 0.12%
# 'Algeria': 0.07%
# 'New Zealand']: 0.44%
# ['Sweden': 0.14%
# 'Slovakia': 0.02%
# 'Tunisia': 0.01%
# 'Bulgaria': 0.23%
# 'Kazakhstan']: 0.01%
# 'Colombia']: 0.06%
# ['Taiwan': 0.02%
# 'Russia']: 0.21%
# 'Poland']: 0.03%
# ['Romania': 0.00%
# 'Lebanon']: 0.00%
# 'India': 1.58%
# 'Bosnia and Herzegovina': 0.00%
# 'Turkey': 0.02%
# 'Sudan']: 0.00%
# ['Portugal': 0.00%
# 'Brazil']: 0.17%
# 'Israel']: 0.01%
# ['Poland']: 0.01%
# 'Uruguay': 0.00%
# ['Ireland']: 0.00%
# 'Argentina']: 0.17%
# ['Vietnam': 0.00%
# ['Puerto Rico': 0.00%
# 'Norway': 0.10%
# ['South Africa']: 0.00%
# 'Portugal': 0.01%
# 'Slovenia': 0.10%
# 'Guatemala': 0.09%
# 'Singapore': 0.59%
# 'Ukraine']: 0.03%
# 'Monaco': 0.04%
# 'United Arab Emirates': 0.45%
# 'Finland': 0.01%
# 'Lithuania']: 0.00%
# 'Bahrain']: 0.00%
# ['Japan': 0.86%
# ['Austria']: 0.00%
# 'Senegal': 0.00%
# 'Egypt']: 0.00%
# 'Russia': 0.20%
# 'Cayman Islands']: 0.00%
# ['Unknown Country']: 0.02%
# 'Sweden']: 0.05%
# ['Sweden']: 0.00%
# 'Finland']: 0.03%
# 'Tunisia']: 0.00%
# ['Ethiopia': 0.00%
# 'Peru': 0.10%
# 'Chile']: 0.01%
# ['Chile': 0.02%
# ['Iceland': 0.00%
# ['Colombia']: 0.00%
# ['Finland': 0.13%
# 'Jordan': 0.35%
# 'Chile': 0.02%
# 'Kuwait': 0.00%
# 'Jordan']: 0.14%
# ['Iran': 0.00%
# ['Dominican Republic']: 0.00%
# 'Vietnam']: 0.04%
# ['Greece']: 0.00%
# ['Peru': 0.00%
# 'Colombia': 0.04%
# 'Occupied Palestinian Territory': 0.00%
# 'Saudi Arabia']: 0.01%
# ['Serbia': 0.01%
# ['Vietnam']: 0.01%
# 'Bosnia and Herzegovina']: 0.00%
# 'Peru']: 0.00%
# 'Algeria']: 0.00%
# ['Estonia': 0.00%
# ['Iceland']: 0.00%
# 'Vietnam': 0.22%
# ['United Arab Emirates': 0.02%
# 'Iran']: 0.00%
# 'Philippines']: 0.00%
# ['The Democratic Republic of Congo': 0.00%
# 'Venezuela']: 0.00%
# ['Venezuela']: 0.00%
# 'Tanzania']: 0.00%
# 'Nigeria']: 0.00%
# 'Chad']: 0.00%
# 'Ukraine': 0.07%
# 'Cambodia': 0.25%
# 'Serbia']: 0.01%
# 'Botswana']: 0.00%
# 'Lebanon': 0.00%
# 'Egypt': 0.00%
# 'Qatar']: 0.07%
# 'Bolivia': 0.00%
# ['Pakistan']: 0.00%
# 'Bermuda']: 0.00%
# ['Taiwan']: 0.03%
# 'Albania': 0.00%
# 'Venezuela': 0.00%
# 'Malaysia': 0.00%
# 'Sri Lanka': 0.00%
# 'Afghanistan']: 0.00%
# 'Central African Republic']: 0.00%
# 'Cuba']: 0.00%
# ['Georgia': 0.00%
# ['Greece': 0.00%
# 'Singapore']: 0.01%
# ['Lebanon': 0.01%
# 'Qatar': 0.02%
# ['Saudi Arabia': 0.00%
# 'Rwanda']: 0.00%
# 'Rwanda': 0.00%
# ['Paraguay': 0.00%
# ['Turkey']: 0.01%
# ['Pakistan': 0.00%
# 'Guatemala']: 0.00%
# 'Afghanistan': 0.00%
# ['Occupied Palestinian Territory']: 0.00%
# 'Ecuador': 0.00%
# ['Nigeria': 0.00%
# 'Georgia']: 0.00%
# 'Costa Rica']: 0.00%
# ['Venezuela': 0.00%
# 'Laos']: 0.00%
# ['Singapore']: 0.00%
# ['Cambodia': 0.00%
# 'Haiti': 0.00%
# ['Nepal': 0.00%
# ['Jordan': 0.00%
# 'Indonesia']: 0.00%
# 'Serbia and Montenegro']: 0.00%
# 'Senegal']: 0.00%
# 'Cyprus']: 0.00%
# 'Zambia']: 0.17%
# 'Iraq': 0.11%
# 'Nepal']: 0.01%
# ['Morocco': 0.00%
# ['Kenya': 0.00%
# ['Indonesia': 0.00%
# 'Mauritania': 0.00%
# ['Qatar': 0.00%
# 'Puerto Rico': 0.00%
# 'Panama']: 0.00%
# ['Ukraine': 0.00%
# 'Indonesia': 0.01%
# ['Bahamas': 0.00%
# ['Latvia': 0.00%
# ['Bolivia']: 0.00%
# 'Chad': 0.00%
# ['Singapore': 0.00%
# ['United Arab Emirates']: 0.00%
# 'Malaysia']: 0.03%
# 'Ghana']: 0.00%
# ['Guatemala': 0.00%
# 'Latvia']: 0.00%
# 'Estonia': 0.00%
# 'Occupied Palestinian Territory']: 0.00%
# 'Costa Rica': 0.00%
# 'Vanuatu']: 0.00%
# ['Senegal': 0.00%
# 'Puerto Rico']: 0.27%
# 'Malta']: 0.33%
# ['Panama': 0.00%
# 'Mongolia': 0.00%
# 'Dominican Republic': 0.00%
# ['Slovakia': 0.00%
# ['Belarus']: 0.00%
# 'Mali']: 0.00%
# ['Hungary']: 0.00%
# 'Cyprus': 0.01%
# 'Liberia']: 0.00%
# 'Bangladesh': 0.00%
# 'Iraq']: 0.00%
# ['Cuba': 0.00%
# 'Ghana': 0.00%
# 'Myanmar']: 0.02%
# ['Swaziland': 0.00%
# 'Kenya']: 0.36%
# 'Namibia': 0.00%
# 'Zimbabwe': 0.00%
# 'Croatia']: 0.09%
# 'Vatican': 0.00%
# 'Serbia': 0.25%
# 'Sri Lanka']: 0.00%
# 'Bermuda': 0.00%
# 'Lithuania': 0.01%
# 'Guadeloupe']: 0.01%
# ['North Macedonia': 0.00%
# 'Georgia': 0.00%
# 'Syria']: 0.00%
# 'Syria': 0.00%
# ['Serbia']: 0.00%
# ['The Democratic Republic of Congo']: 0.00%
# ['Nigeria']: 0.00%
# ['Bangladesh']: 0.00%
# 'Belarus']: 0.00%
# 'Montenegro': 0.00%
# 'Niger']: 0.00%
# 'Slovenia']: 0.00%
# 'Monaco']: 0.00%
# ['Croatia': 0.01%
# ['Chad': 0.00%
# 'Uganda']: 0.00%
# ['Egypt': 0.00%
# ['Estonia']: 0.00%
# ['Malta': 0.00%
# ['Finland']: 0.00%
# ['Bulgaria': 0.01%
# ['Armenia']: 0.00%
# ['Bangladesh': 0.00%
# ['Bolivia': 0.00%
# ['Lithuania': 0.00%
# 'Uganda': 0.00%
# 'Bangladesh']: 0.00%
# ['Indonesia']: 0.00%
# 'Angola']: 0.00%
# ['Ukraine']: 0.00%
# 'Panama': 0.00%
# 'Kosovo': 0.00%
# ['Bhutan': 0.00%
# 'Saudi Arabia': 0.00%
# 'The Democratic Republic of Congo': 0.00%
# 'Madagascar']: 0.00%
# 'Gambia']: 0.16%
# 'Haiti']: 0.00%
# 'Benin': 0.00%
# ['Malaysia']: 0.00%
# ['Latvia']: 0.00%

# %% [markdown]
# ### **EDA로 시각화할 주요 관계**
#
# 1. **장르별 평균 제작비 vs 수익 시각화**
#     - 장르가 수익성에 미치는 영향을 막대 그래프로 표현
# 2. **연도별 상위 평점 영화 개수**
#     - 시간에 따른 트렌드를 꺾은선 그래프로 나타냄
# 3. **러닝타임(Duration) vs 평점(Rating)**
#     - 러닝타임과 평점 간의 관계를 산점도로 시각화
# 4. **제작비(Budget)와 글로벌 수익(GrossWorldwide)**
#     - 제작비 대비 수익성을 산점도 및 회귀선을 이용하여 표현

# %%
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['grossWorldWide'] = pd.to_numeric(df['grossWorldWide'], errors='coerce')



# 장르별 평균 제작비와 평균 수익 계산
genre_avg_budget = df.groupby('Category')['budget'].mean()
genre_avg_gross = df.groupby('Category')['grossWorldWide'].mean()

# 천 단위 구분 및 통화 기호 추가 함수
def currency(x, pos):
    return f"${x:,.0f}"

# 장르별 평균 제작비와 평균 수익을 하나의 데이터프레임으로 합치기
genre_comparison = pd.DataFrame({
    '평균 제작비': genre_avg_budget,
    '평균 수익': genre_avg_gross
})

# 그래프 시각화
fig, ax = plt.subplots(figsize=(12, 8))

width = 0.35  # 막대 너비
genre_comparison.plot(kind='bar', ax=ax, width=width)

ax.set_xlabel('장르')
ax.set_ylabel('금액 (단위: $)')
ax.set_title('장르별 평균 제작비와 수익')

# x축 레이블 회전
plt.xticks(rotation=90)

# y축과 x축에 천 단위 구분과 통화 기호 적용
ax.yaxis.set_major_formatter(FuncFormatter(currency))

plt.tight_layout()
plt.show()

# %%
# IMDb 평점이 높은 영화만 필터링 (예: 평점 8.0 이상)
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
top_rated_movies = df[df['Rating'] >= 8.0]

# 연도별 상위 평점 영화 개수 계산
top_rated_by_year = top_rated_movies.groupby('Year')['Title'].count()

# 꺾은선 그래프 시각화
plt.figure(figsize=(10, 6))
plt.plot(top_rated_by_year.index, top_rated_by_year.values, marker='o', color='b', label='상위 평점 영화 개수')
plt.xlabel('연도')
plt.ylabel('영화 개수')
plt.title('연도별 상위 평점 영화 개수')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df['budget'], df['grossWorldWide'], alpha=0.5, color='g')

# 회귀선 추가
X = df['budget'].values.reshape(-1, 1)
y = df['grossWorldWide'].values
regressor = LinearRegression()
regressor.fit(X, y)
y_pred = regressor.predict(X)

plt.plot(X, y_pred, color='b', linewidth=2)

# 천 단위 구분 및 통화 기호 추가
def currency(x, pos):
    return f"${x:,.0f}"

# X축과 Y축에 천 단위 구분과 통화 기호 적용
plt.gca().xaxis.set_major_formatter(FuncFormatter(currency))
plt.gca().yaxis.set_major_formatter(FuncFormatter(currency))

plt.xlabel('제작비 (Budget)')
plt.ylabel('글로벌 수익 (Gross Worldwide)')
plt.title('제작비 vs 글로벌 수익 (회귀선 포함)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **데이터 전처리 주요 포인트**
#
# - 결측값 처리 (예: 제작비, 수익, 평점)
# - 연속형 변수(예: Budget, GrossWorldwide)의 로그 변환으로 분포 조정
# - 감독, 배우 등 다중 텍스트 데이터를 리스트 형태로 처리
# - 장르, 언어 등 범주형 변수의 One-hot Encoding 또는 Label Encoding
